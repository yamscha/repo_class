# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target urls and multiple API requests.

# Dependencies
import requests
import json
#from localeny import api_key
from localeny import api_key
#api_key="AIzaSyASZK6DhLdP4twNLluCiMiioz7WcgiDpUQ"
# Retrieve Google API key from localenv.py

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
address="Berkeley,California"
api_key ="AIzaSyASZK6DhLdP4twNLluCiMiioz7WcgiDpUQ"

query_url=f"{base_url}?address={address}&key={api_key}"

response = requests.get(query_url)
print(response.url)
google_code = response.json()
#google_code
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?address=Berkeley,California&key=AIzaSyASZK6DhLdP4twNLluCiMiioz7WcgiDpUQ

# %%
# 1. What are the geocoordinates (latitude/longitude) of Berkeley, California
param = {"address": "Berkeley, California", "key":api_key}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
            
print("\r\nDrill #1")

response = requests.get(base_url,params=param)
print(response.url)
geo=response.json()
#geo
# Out:
# Drill #1
# https://maps.googleapis.com/maps/api/geocode/json?address=Berkeley%2C+California&key=AIzaSyASZK6DhLdP4twNLluCiMiioz7WcgiDpUQ

# %%
base_url = "https://maps.googleapis.com/maps/api/geocode/json"
address1 = "White House,DC"
api_key ="AIzaSyASZK6DhLdP4twNLluCiMiioz7WcgiDpUQ"

query_url= f"{base_url}?address={address1}&key={api_key}"
response1 = requests.get(query_url)
white_house_geo=response1.json()
white_house_geo
# Out:
# {'results': [{'address_components': [{'long_name': '1600',
#      'short_name': '1600',
#      'types': ['street_number']},
#     {'long_name': 'Pennsylvania Avenue Northwest',
#      'short_name': 'Pennsylvania Ave NW',
#      'types': ['route']},
#     {'long_name': 'Northwest Washington',
#      'short_name': 'Northwest Washington',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Washington',
#      'short_name': 'Washington',
#      'types': ['locality', 'political']},
#     {'long_name': 'District of Columbia',
#      'short_name': 'DC',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
#    'formatted_address': '1600 Pennsylvania Ave NW, Washington, DC 20500, USA',
#    'geometry': {'location': {'lat': 38.8976763, 'lng': -77.0365298},
# ...

# %%
# 1. What are the geocoordinates (latitude/longitude) of Berkeley, California
# 2. What are the geocoordinates (latitude/longitude) of The White House?
lat = white_house_geo["results"][0]["geometry"]["location"]["lat"]
longitude = white_house_geo["results"][0]["geometry"]['location']["lng"]
print(lat,longitude)
# Out:
# 38.8976763 -77.0365298

# %%
# 3. Find the names and addresses of a bike store in Berkeley, California
#    Hint: See https://developers.google.com/places/web-service/supported_types
target_type ="bicycle_store"
coords = "37.8715926,-122.272747"
radius = 8000

parameters = {"location":coords,
              "type":target_type,
              "radius":radius,
               "key":place_key}
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url,parameters)
req = response.json()
req

print(req["results"][0]["name"])
print(req["results"][0]["vicinity"])
# Out:
# REI
# 1338 San Pablo Avenue, Berkeley

# %%
param1 = {"address": "White House, DC", "key":api_key}

base_url = "https://maps.googleapis.com/maps/api/geocode/json"
            
print("\r\nDrill #1")

response = requests.get(base_url,params=param1)
print(response.url)
geo=response.json()
geo
# Out:
# Drill #1
# https://maps.googleapis.com/maps/api/geocode/json?address=White+House%2C+DC&key=AIzaSyASZK6DhLdP4twNLluCiMiioz7WcgiDpUQ
# {'results': [{'address_components': [{'long_name': '1600',
#      'short_name': '1600',
#      'types': ['street_number']},
#     {'long_name': 'Pennsylvania Avenue Northwest',
#      'short_name': 'Pennsylvania Ave NW',
#      'types': ['route']},
#     {'long_name': 'Northwest Washington',
#      'short_name': 'Northwest Washington',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'Washington',
#      'short_name': 'Washington',
#      'types': ['locality', 'political']},
#     {'long_name': 'District of Columbia',
#      'short_name': 'DC',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '20500', 'short_name': '20500', 'types': ['postal_code']}],
# ...

# %%
# 4. Find a balloon store near the White House.
target_type="baloon store"
dc_coords =  "38.8976763,-77.0365298"
radius=8000
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
param2 ={"location":dc_coords,
         "type":target_type,
        "radius":radius,
         "key":place_key}
response = requests.get(base_url,param2)
req = response.json()
req
print(req['results'][0]['name'])
print(req['results'][0]['vicinity'])
# Out:
# Washington
# Washington

# %%
req
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHQEAAOfjQx5lV15YC4UnxPCgGbi9paeiUNYzgBLrDl8Xa0J3K85C2Pn3xkA9dKumVrS_qxxgL8SAmDpAjiRv7g_vPOOvi2kdJrkdBc5v0zhLl7d0D6BmFoS4IDXH7P6yhUHcpyX6P6zZ2Deuw_tFbktTX-Kf0HEhpCjwLYo6h0GqkfGs9rIgoUNkNqFYt4vV4d1fDXfWaVvntJxYoVgBhWW0WKgaJ_HiI8vyhtYZOuObg7ek8hZihI2MLpT6pDGpcYawlZapprgxdh7BVcC_5Vv2Sbk7BIMv5whFjGLLEysu28bzP9J8sf81dZNNl_49qNKhMByD8uhHkFVkszmXEwJ7XZKTD1_OuPaCuGUf9yhXEirmS65M7GoUWfdhTo6jsU4VNhIQAt57tTEBdoJY0F9ZU9vaCRoU6QlFILYRT2OXjXsNJjyS83kau7E',
#  'results': [{'geometry': {'location': {'lat': 38.9071923, 'lng': -77.0368707},
#     'viewport': {'northeast': {'lat': 38.995548, 'lng': -76.909393},
#      'southwest': {'lat': 38.7916449, 'lng': -77.119759}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#    'id': '49c0cb4aa94c88be75611d5c80f29cf05d55a340',
#    'name': 'Washington',
#    'photos': [{'height': 786,
# ...

# %%
# 5. Find the nearest dentist to your house.
#    Hint: Use Google Maps to find your latitude and Google Places to find the
#    dentist. You will also need the rankby property.

# %%
# 6. Bonus: Find the names and addresses of the top five places Google suggests
#    for the phrase: "Happy Place ".
#    Hint: Read about "Text Search Results"
# (https://developers.google.com/places/web-service/search#TextSearchRequests)
