# %%
# Dependencies
import pandas as pd

# %%
# load CSV

new_coders = "../Resources/2016-FCC-New-Coders-Survey-Data.csv"

# %%
# Read with pandas

new_coders_pd= pd.read_csv(new_coders, encoding="iso-8859-1", low_memory=False)
new_coders_pd.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber       ...       ResourceSoloLearn  \
# ...

# %%
# Inspect all columns

new_coders_pd.columns
# Out:
# Index(['Age', 'AttendedBootcamp', 'BootcampFinish', 'BootcampFullJobAfter',
#        'BootcampLoanYesNo', 'BootcampMonthsAgo', 'BootcampName',
#        'BootcampPostSalary', 'BootcampRecommend', 'ChildrenNumber',
#        ...
#        'ResourceSoloLearn', 'ResourceStackOverflow', 'ResourceTreehouse',
#        'ResourceUdacity', 'ResourceUdemy', 'ResourceW3Schools',
#        'ResourceYouTube', 'SchoolDegree', 'SchoolMajor', 'StudentDebtOwe'],
#       dtype='object', length=113)

# %%
# Extract only columns 0, 1, 2, 3, 4, 7, 8, 9, 10,11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111 

reduced_coders_pd = new_coders_pd.iloc[:,[0,1,2,3,4,7,8,9,10,11,29,30,32,36,37,45,48,56,110,111]]

reduced_coders_pd.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampPostSalary  BootcampRecommend  ChildrenNumber  \
# 0                NaN                 NaN                NaN             NaN
# 1                NaN                 NaN                NaN             NaN
# 2                NaN                 NaN                NaN             NaN
# 3                NaN                 NaN                NaN             NaN
# 4                NaN                 NaN                NaN             NaN
#
#                   CityPopulation  CodeEventBootcamp               CountryLive  \
# ...

# %%
# Change "0" to "No" and "1" to "Yes" in response columns
reduced_coders_pd = reduced_coders_pd.replace({0:"No",1:"Yes"})
reduced_coders_pd.head()
# Out:
#     Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0  28.0               No            NaN                  NaN
# 1  22.0               No            NaN                  NaN
# 2  19.0               No            NaN                  NaN
# 3  26.0               No            NaN                  NaN
# 4  20.0               No            NaN                  NaN
#
#   BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 0               NaN                 NaN               NaN            NaN
# 1               NaN                 NaN               NaN            NaN
# 2               NaN                 NaN               NaN            NaN
# 3               NaN                 NaN               NaN            NaN
# 4               NaN                 NaN               NaN            NaN
#
#                   CityPopulation CodeEventBootcamp               CountryLive  \
# 0  between 100,000 and 1 million               NaN  United States of America
# ...

# %%
# Calculate total number of respondents in survey

total_surveyed=len(reduced_coders_pd)
total_surveyed
# Out:
# 15620

# %%
# Extract rows corresponding only to people who attended a bootcamp
attended_bootcamp = reduced_coders_pd.loc[reduced_coders_pd["AttendedBootcamp"] == "Yes"]
attended_bootcamp.head()
# Out:
#       Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 93   32.0              Yes            Yes                   No
# 97   26.0              Yes            Yes                  Yes
# 130  41.0              Yes            Yes                  Yes
# 159  26.0              Yes            Yes                   No
# 188  24.0              Yes             No                  NaN
#
#     BootcampLoanYesNo  BootcampPostSalary BootcampRecommend ChildrenNumber  \
# 93                 No                 NaN                No            NaN
# 97                 No             45000.0                No            NaN
# 130               Yes             75000.0               Yes              3
# 159                No                 NaN                No            NaN
# 188               Yes                 NaN                No            NaN
#
#                     CityPopulation CodeEventBootcamp  \
# 93   between 100,000 and 1 million               NaN
# ...

# %%
# Calculate average age of attendees 
average_age = attended_bootcamp["Age"].mean()
print(average_age)
# Out:
# 31.066014669926652

# %%
# Calculate how many people attended a bootcamp
count_people=attended_bootcamp["AttendedBootcamp"].count()
print(count_people)
# Out:
# 953

# %%
#Calculate how many attendees hold degrees
count_hold_degrees=attended_bootcamp["SchoolDegree"].count()
#count_hold_degrees=attended_bootcamp["SchoolDegree"].value_counts()
print(count_hold_degrees)
# Out:
# 832

# %%
# Count number of attendees who self-identify as male; female; or are of non-binary gender identification  
total_no_attendees = attended_bootcamp["Gender"].count()
male_count = attended_bootcamp["Gender"].value_counts()["male"]
female_count = attended_bootcamp["Gender"].value_counts()["female"]
print("Total:",total_no_attendees)
print("Male_Count:",male_count)
print("Female_Count:",female_count)
# Out:
# Total: 833
# Male_Count: 496
# Female_Count: 326

# %%
# Calculate percentage of respondents who attended a bootcamp
percentage_respondents =count_people/total_surveyed*100
print(percentage_respondents)
# Out:
# 6.101152368758003

# %%
# Calculate percentage of respondents belonging to each gender
male_gender_percent = male_count/total_no_attendees*100
female_gender_percent = female_count/total_no_attendees*100

print("male_gender_percent:",male_gender_percent)
print("female_gender_percent:",female_gender_percent)
# Out:
# male_gender_percent: 59.5438175270108
# female_gender_percent: 39.13565426170468

# %%
# Calculate percentage of attendees with a school degree
percentage_school_degree=count_hold_degrees/count_people*100

print(percentage_school_degree)
# Out:
# 87.30325288562435

# %%
# Calculate average post-bootcamp salary
average_post_bootcamp_salary=attended_bootcamp["BootcampPostSalary"].mean()
print(average_post_bootcamp_salary)
# Out:
# 63740.50606060606

# %%
# Create a new table consolodating above calculations

# %%
# Improve formatting before outputting spreadsheet
# Out:
#    Total Surveyed  Total Bootcamp attendees % attended bootcamp  Avg. Age  \
# 0           15620                       953               6.10%     31.07
#
#   Has a degree  % Male % Female % Non Gender Specific  \
# 0       87.30%  59.54%   39.14%                 1.32%
#
#   Average Post Bootcamp Salary
# 0                      $63,741

# %%
# Export to Excel
