# %%
import pandas as pd
import os

# %%
file = os.path.join('Resources', 'KickstarterData.csv')

df=pd.read_csv(file)

# %%
df.head()
# Out:
#            id                                              photo  \
# 0  1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1   874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3  1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4   421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  The Class Act Players Theatre Company Presents...
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2                                                RUN
# 3  9th International Meeting of Youth Theatre sap...
# 4                        Get Conti to the Ed Fringe!
#
#                                                blurb    goal  pledged  \
# 0  The Class Act Players put on another one of th...  1500.0   2925.0
# 1  A brand new play about love and entitlement, b...  2500.0   2936.0
# ...

# %%
df
# Out:
#               id                                              photo  \
# 0     1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1      874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2      247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 3     1941196813  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4      421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 5      319700919  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 6      177484975  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 7      601170861  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 8     1523103519  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 9      477372304  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 10    1302269979  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 11    1491852635  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 12    1440808021  {"small":"https://ksr-ugc.imgix.net/assets/012...
# ...

# %%
df.shape
# Out:
# (4120, 33)

# %%
df.columns
# Out:
# Index(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'is_starrable', 'backers_count',
#        'static_usd_rate', 'usd_pledged', 'creator', 'location', 'category',
#        'profile', 'spotlight', 'urls', 'source_url', 'friends', 'is_starred',
#        'is_backing', 'permissions'],
#       dtype='object')

# %%
df.dytpes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-59e447e3e092> in <module>()
# ----> 1 df.dytpes
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dytpes'

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-09616d73ed79> in <module>()
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
df.dtypes
# Out:
# id                          int64
# photo                      object
# name                       object
# blurb                      object
# goal                      float64
# pledged                   float64
# state                      object
# slug                       object
# disable_communication        bool
# country                    object
# currency                   object
# currency_symbol            object
# currency_trailing_code       bool
# deadline                    int64
# state_changed_at            int64
# created_at                  int64
# launched_at                 int64
# staff_pick                   bool
# is_starrable                 bool
# backers_count               int64
# static_usd_rate           float64
# usd_pledged               float64
# creator                    object
# location                   object
# category                   object
# profile                    object
# spotlight                    bool
# ...

# %%
df.columns
# Out:
# Index(['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug',
#        'disable_communication', 'country', 'currency', 'currency_symbol',
#        'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at',
#        'launched_at', 'staff_pick', 'is_starrable', 'backers_count',
#        'static_usd_rate', 'usd_pledged', 'creator', 'location', 'category',
#        'profile', 'spotlight', 'urls', 'source_url', 'friends', 'is_starred',
#        'is_backing', 'permissions'],
#       dtype='object')

# %%
#slicing/subsetting data
#one coulmn outof dataset---df['name-col']

column_df=df[['state','name']]

# %%
column_df.head()
# Out:
#         state                                               name
# 0  successful  The Class Act Players Theatre Company Presents...
# 1  successful  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2  successful                                                RUN
# 3  successful  9th International Meeting of Youth Theatre sap...
# 4  successful                        Get Conti to the Ed Fringe!

# %%
df[[2]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-22b465a0eb2f> in <module>()
# ----> 1 df[[2]]
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# ...

# %%
#subset rows
df.loc[[0,1,2]]
# Out:
#            id                                              photo  \
# 0  1645666704  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 1   874638240  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 2   247074984  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                                 name  \
# 0  The Class Act Players Theatre Company Presents...
# 1  MR INCREDIBLE by Camilla Whitehill - VAULT Fes...
# 2                                                RUN
#
#                                                blurb    goal  pledged  \
# 0  The Class Act Players put on another one of th...  1500.0   2925.0
# 1  A brand new play about love and entitlement, b...  2500.0   2936.0
# 2  Yonni's pissed off in a world filled with scho...  1000.0   1200.0
#
#         state                                               slug  \
# 0  successful  the-class-act-players-theatre-company-presents...
# 1  successful  mr-incredible-by-camilla-whitehill-vault-festival
# ...

# %%
df.loc['RUN']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in _has_valid_type(self, key, axis)
#    1505                 if not ax.contains(key):
# -> 1506                     error()
#    1507             except TypeError as e:
#
# ~\Anaconda3\envs\pythondata\lib\site-packages\pandas\core\indexing.py in error()
#    1500                                .format(key=key,
# -> 1501                                        axis=self.obj._get_axis_name(axis)))
#    1502
#
# KeyError: 'the label [RUN] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-ee1b859bc912> in <module>()
# ----> 1 df.loc['RUN']
#
# ...

# %%
df.iloc(1)

# %%
df.iloc[123]
# Out:
# id                                                               1849431368
# photo                     {"small":"https://ksr-ugc.imgix.net/assets/011...
# name                                      FLOOR: The Flint Order of Orpheus
# blurb                     Help Connor and Mary (and Gothic Funk Press) p...
# goal                                                                    100
# pledged                                                                 181
# state                                                            successful
# slug                                       floor-the-flint-order-of-orpheus
# disable_communication                                                 False
# country                                                                  US
# currency                                                                USD
# currency_symbol                                                           $
# ...

# %%
df.ix[[56,78,4]]
# Out:
#             id                                              photo  \
# 56   212696510  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 78  1801443687  {"small":"https://ksr-ugc.imgix.net/assets/012...
# 4    421961595  {"small":"https://ksr-ugc.imgix.net/assets/012...
#
#                                            name  \
# 56  Portrait by Above Bounds Theatre Collective
# 78                           Pride Varberg 2015
# 4                   Get Conti to the Ed Fringe!
#
#                                                 blurb     goal  pledged  \
# 56  Portrait is Above Bounds new family show which...    600.0    648.0
# 78  Massor av kärlek inbakat i en asball festival!...  10000.0  10920.0
# 4   The Italia Conti 2nd years are going to Ed Fri...   1000.0   1250.0
#
#          state                                         slug  \
# 56  successful  portrait-by-above-bounds-theatre-collective
# 78  successful                           pride-varberg-2015
# ...

# %%
df.ix[[56,78,4],'goal']
# Out:
# 56      600.0
# 78    10000.0
# 4      1000.0
# Name: goal, dtype: float64
