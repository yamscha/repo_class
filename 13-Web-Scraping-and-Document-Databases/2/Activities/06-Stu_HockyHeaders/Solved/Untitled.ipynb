# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pymongo
import pandas as pd

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.nhl_db
collection = db.articles

# %%
# URL of page to be scraped
url = 'https://www.nhl.com/'

# %%
# Retrieve page with the requests module
response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
soup = BeautifulSoup(response.text, 'lxml')

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('li', class_='mixed-feed__item--article')

# %%
# Loop through results to retrieve article title, header, and timestamp of article
for result in results:
    title = result.find('h4', class_='mixed-feed__header').text

    lede = result.find('h5', class_='mixed-feed__subheader').text

    # The time and date of article publication
    date = result.find('time')['datetime']
    # Slice the datetime string for the date
    article_date = date[:10]
    # Slice the datetime string for the time
    time = date[11:16]
    # Determine whether article was published in AM or PM
    if (int(time[:2]) >= 13):
        meridiem = 'pm'
    else:
        meridiem = 'am'

    # Concatenate time string
    time = time + meridiem
    print('-----------------')
    print(title)
    print(lede)
    print(article_date)
    print(time)

    # Dictionary to be inserted into MongoDB
    post = {
        'title': title,
        'lede': lede,
        'date': article_date,
        'time published': time
    }

    # Insert dictionary into MongoDB as a document
    collection.insert_one(post)
# Out:
# -----------------
# Kadri suspension has Maple Leafs adjusting for Game 2 against Bruins
# Toronto aims to even series in Boston without forward
# 2018-04-13
# 21:26pm
# -----------------
# Couturier's transition to scorer for Flyers evident in playoffs
# Former checking-line center making offensive impact against Penguins
# 2018-04-14
# 11:09am
# -----------------
# Stanley Cup Playoffs Buzz: Avalanche, Devils try to bounce back
# Maple Leafs, Ducks also seek to even series after losing openers
# 2018-04-14
# 09:41am
# -----------------
# Kings look for Quick to stand tall against Golden Knights in Game 3
# Los Angeles, down 2-0 in first-round series, aims for better play in front of goaltender after 54-save performance
# 2018-04-14
# 10:50am
# -----------------
# Golden Knights make more history with double-overtime win against Kings
# Vegas is third team with multi-OT victory in inaugural NHL season, fifth to capture first two playoff games
# 2018-04-14
# 11:40am
# -----------------
# Byfuglien has huge 'impact' for Jets in Game 2 win against Wild
# Defenseman excites fans with big hit on Koivu behind net
# 2018-04-14
# 01:33am
# -----------------
# Where to watch 2018 Stanley Cup Playoffs
# Viewer's guide for upcoming NHL postseason games
# 2018-04-13
# 10:23am
# -----------------
# Fantasy projected lineups, starting goalies
# Updates from NHL.com correspondents, teams, reports
# 2018-04-14
# 13:50pm
# -----------------
# Kadri suspended three games, out for Maple Leafs starting in Game 2
# Forward disciplined for boarding Bruins forward Wingels
# 2018-04-13
# 18:01pm
# -----------------
# Flyers stick with plan, respond in Game 2
# Even Eastern series with Penguins behind performances by Elliott, Couturier
# 2018-04-14
# 01:01am
# -----------------
# Watch every overtime goal in Stanley Cup Playoffs
# Haula scores for Golden Knights in second OT of Game 2 of Western Conference First Round against Kings
# 2018-04-14
# 02:31am
# -----------------
# Douglas: Players of color have pivotal roles in opening games of playoffs
# Blog: Kane, Smith-Pelly, Jones, Byfuglien, Greenway stand out
# 2018-04-14
# 12:02am
# -----------------
# Get to know Erik Haula, Golden Knights' first playoff overtime hero
# Native of Finland was selected from Wild in expansion draft
# 2018-04-14
# 02:58am
# -----------------
# Capitals understand urgency surrounding Game 2 against Blue Jackets
# Opening loss has favored Washington feeling pressure at all-too-familiar crossroads
# 2018-04-13
# 13:23pm
# -----------------
# Hitchcock praised by Bowman, Babcock upon retiring as Stars coach
# 66-year-old, with third-most NHL wins, 'one of the best ever'
# 2018-04-13
# 20:08pm
# -----------------
# Bruins' power-play surge carries into playoffs
# Scored three man-advantage goals in opener vs. Maple Leafs after strong regular-season finish
# 2018-04-13
# 16:02pm
# -----------------
# Fantasy: 10 playoff sleeper candidates for 2018
# Watson underrated for Predators; Cirelli, Donato potential impact rookies
# 2018-04-13
# 16:15pm
# -----------------
# Hitchcock retires as Stars coach, third in NHL wins
# 66-year-old will remain with Dallas as consultant
# 2018-04-13
# 11:11am
# -----------------
# Ken Hitchcock career timeline
# Third-winningest coach in NHL history retired after 21 seasons
# 2018-04-13
# 11:32am
# -----------------
# Maple Leafs looking for answers after Game 1 loss to Bruins
# Penalties, special-teams woes sink Toronto in series opener
# 2018-04-13
# 10:46am
# -----------------
# Fantasy: Playoff X-factor for each team in 2018
# Grubauer starting for Capitals; Henrique, Hertl look to build on playoff success
# 2018-04-12
# 10:00am
# -----------------
# Fantasy: Rankings for 2018 Stanley Cup Playoffs
# NHL.com lists most valuable forwards, defensemen, goaltenders for basic postseason pools
# 2018-04-12
# 11:00am
# -----------------
# Stanley Cup Playoffs first-round schedule
# Penguins, Golden Knights eye history
# 2018-04-12
# 00:43am

# %%
# Display the MongoDB records created above
articles = db.articles.find()
result = []
for article in articles:
   # print(article)
    result.append(article)

# %%
result
# Out:
# [{'_id': ObjectId('5ad24c0239fa064690109231'),
#   'date': '2018-04-13',
#   'lede': 'Toronto aims to even series in Boston without forward',
#   'time published': '21:26pm',
#   'title': 'Kadri suspension has Maple Leafs adjusting for Game 2 against Bruins'},
#  {'_id': ObjectId('5ad24c0239fa064690109232'),
#   'date': '2018-04-14',
#   'lede': 'Former checking-line center making offensive impact against Penguins',
#   'time published': '11:09am',
#   'title': "Couturier's transition to scorer for Flyers evident in playoffs"},
#  {'_id': ObjectId('5ad24c0239fa064690109233'),
#   'date': '2018-04-14',
#   'lede': 'Maple Leafs, Ducks also seek to even series after losing openers',
#   'time published': '09:41am',
#   'title': 'Stanley Cup Playoffs Buzz: Avalanche, Devils try to bounce back'},
#  {'_id': ObjectId('5ad24c0239fa064690109234'),
#   'date': '2018-04-14',
#   'lede': 'Los Angeles, down 2-0 in first-round series, aims for better play in front of goaltender after 54-save performance',
#   'time published': '10:50am',
#   'title': 'Kings look for Quick to stand tall against Golden Knights in Game 3'},
#  {'_id': ObjectId('5ad24c0239fa064690109235'),
#   'date': '2018-04-14',
#   'lede': 'Vegas is third team with multi-OT victory in inaugural NHL season, fifth to capture first two playoff games',
#   'time published': '11:40am',
#   'title': 'Golden Knights make more history with double-overtime win against Kings'},
#  {'_id': ObjectId('5ad24c0239fa064690109236'),
#   'date': '2018-04-14',
#   'lede': 'Defenseman excites fans with big hit on Koivu behind net',
#   'time published': '01:33am',
#   'title': "Byfuglien has huge 'impact' for Jets in Game 2 win against Wild"},
#  {'_id': ObjectId('5ad24c0239fa064690109237'),
#   'date': '2018-04-13',
#   'lede': "Viewer's guide for upcoming NHL postseason games",
#   'time published': '10:23am',
#   'title': 'Where to watch 2018 Stanley Cup Playoffs'},
#  {'_id': ObjectId('5ad24c0239fa064690109238'),
#   'date': '2018-04-14',
#   'lede': 'Updates from NHL.com correspondents, teams, reports',
#   'time published': '13:50pm',
#   'title': 'Fantasy projected lineups, starting goalies'},
#  {'_id': ObjectId('5ad24c0239fa064690109239'),
#   'date': '2018-04-13',
#   'lede': 'Forward disciplined for boarding Bruins forward Wingels',
#   'time published': '18:01pm',
#   'title': 'Kadri suspended three games, out for Maple Leafs starting in Game 2'},
#  {'_id': ObjectId('5ad24c0239fa06469010923a'),
#   'date': '2018-04-14',
#   'lede': 'Even Eastern series with Penguins behind performances by Elliott, Couturier',
#   'time published': '01:01am',
#   'title': 'Flyers stick with plan, respond in Game 2'},
#  {'_id': ObjectId('5ad24c0239fa06469010923b'),
#   'date': '2018-04-14',
#   'lede': 'Haula scores for Golden Knights in second OT of Game 2 of Western Conference First Round against Kings',
#   'time published': '02:31am',
#   'title': 'Watch every overtime goal in Stanley Cup Playoffs'},
#  {'_id': ObjectId('5ad24c0239fa06469010923c'),
#   'date': '2018-04-14',
#   'lede': 'Blog: Kane, Smith-Pelly, Jones, Byfuglien, Greenway stand out',
#   'time published': '12:02am',
#   'title': 'Douglas: Players of color have pivotal roles in opening games of playoffs'},
#  {'_id': ObjectId('5ad24c0239fa06469010923d'),
#   'date': '2018-04-14',
#   'lede': 'Native of Finland was selected from Wild in expansion draft',
#   'time published': '02:58am',
#   'title': "Get to know Erik Haula, Golden Knights' first playoff overtime hero"},
#  {'_id': ObjectId('5ad24c0239fa06469010923e'),
#   'date': '2018-04-13',
#   'lede': 'Opening loss has favored Washington feeling pressure at all-too-familiar crossroads',
#   'time published': '13:23pm',
#   'title': 'Capitals understand urgency surrounding Game 2 against Blue Jackets'},
#  {'_id': ObjectId('5ad24c0239fa06469010923f'),
#   'date': '2018-04-13',
#   'lede': "66-year-old, with third-most NHL wins, 'one of the best ever'",
#   'time published': '20:08pm',
#   'title': 'Hitchcock praised by Bowman, Babcock upon retiring as Stars coach'},
#  {'_id': ObjectId('5ad24c0239fa064690109240'),
#   'date': '2018-04-13',
#   'lede': 'Scored three man-advantage goals in opener vs. Maple Leafs after strong regular-season finish',
#   'time published': '16:02pm',
#   'title': "Bruins' power-play surge carries into playoffs"},
#  {'_id': ObjectId('5ad24c0239fa064690109241'),
#   'date': '2018-04-13',
#   'lede': 'Watson underrated for Predators; Cirelli, Donato potential impact rookies',
#   'time published': '16:15pm',
#   'title': 'Fantasy: 10 playoff sleeper candidates for 2018'},
#  {'_id': ObjectId('5ad24c0239fa064690109242'),
#   'date': '2018-04-13',
#   'lede': '66-year-old will remain with Dallas as consultant',
#   'time published': '11:11am',
#   'title': 'Hitchcock retires as Stars coach, third in NHL wins'},
#  {'_id': ObjectId('5ad24c0239fa064690109243'),
#   'date': '2018-04-13',
#   'lede': 'Third-winningest coach in NHL history retired after 21 seasons',
#   'time published': '11:32am',
#   'title': 'Ken Hitchcock career timeline'},
#  {'_id': ObjectId('5ad24c0239fa064690109244'),
#   'date': '2018-04-13',
#   'lede': 'Penalties, special-teams woes sink Toronto in series opener',
#   'time published': '10:46am',
#   'title': 'Maple Leafs looking for answers after Game 1 loss to Bruins'},
#  {'_id': ObjectId('5ad24c0239fa064690109245'),
#   'date': '2018-04-12',
#   'lede': 'Grubauer starting for Capitals; Henrique, Hertl look to build on playoff success',
#   'time published': '10:00am',
#   'title': 'Fantasy: Playoff X-factor for each team in 2018'},
#  {'_id': ObjectId('5ad24c0239fa064690109246'),
#   'date': '2018-04-12',
#   'lede': 'NHL.com lists most valuable forwards, defensemen, goaltenders for basic postseason pools',
#   'time published': '11:00am',
#   'title': 'Fantasy: Rankings for 2018 Stanley Cup Playoffs'},
#  {'_id': ObjectId('5ad24c0239fa064690109247'),
#   'date': '2018-04-12',
#   'lede': 'Penguins, Golden Knights eye history',
#   'time published': '00:43am',
#   'title': 'Stanley Cup Playoffs first-round schedule'}]

# %%
article_db = pd.DataFrame(result)
article_db
# Out:
#                          _id        date  \
# 0   5ad24c0239fa064690109231  2018-04-13
# 1   5ad24c0239fa064690109232  2018-04-14
# 2   5ad24c0239fa064690109233  2018-04-14
# 3   5ad24c0239fa064690109234  2018-04-14
# 4   5ad24c0239fa064690109235  2018-04-14
# 5   5ad24c0239fa064690109236  2018-04-14
# 6   5ad24c0239fa064690109237  2018-04-13
# 7   5ad24c0239fa064690109238  2018-04-14
# 8   5ad24c0239fa064690109239  2018-04-13
# 9   5ad24c0239fa06469010923a  2018-04-14
# 10  5ad24c0239fa06469010923b  2018-04-14
# 11  5ad24c0239fa06469010923c  2018-04-14
# 12  5ad24c0239fa06469010923d  2018-04-14
# 13  5ad24c0239fa06469010923e  2018-04-13
# 14  5ad24c0239fa06469010923f  2018-04-13
# 15  5ad24c0239fa064690109240  2018-04-13
# 16  5ad24c0239fa064690109241  2018-04-13
# 17  5ad24c0239fa064690109242  2018-04-13
# 18  5ad24c0239fa064690109243  2018-04-13
# 19  5ad24c0239fa064690109244  2018-04-13
# 20  5ad24c0239fa064690109245  2018-04-12
# 21  5ad24c0239fa064690109246  2018-04-12
# 22  5ad24c0239fa064690109247  2018-04-12
#
#                                                  lede time published  \
# 0   Toronto aims to even series in Boston without ...        21:26pm
# 1   Former checking-line center making offensive i...        11:09am
# 2   Maple Leafs, Ducks also seek to even series af...        09:41am
# 3   Los Angeles, down 2-0 in first-round series, a...        10:50am
# 4   Vegas is third team with multi-OT victory in i...        11:40am
# 5   Defenseman excites fans with big hit on Koivu ...        01:33am
# 6    Viewer's guide for upcoming NHL postseason games        10:23am
# 7   Updates from NHL.com correspondents, teams, re...        13:50pm
# 8   Forward disciplined for boarding Bruins forwar...        18:01pm
# 9   Even Eastern series with Penguins behind perfo...        01:01am
# 10  Haula scores for Golden Knights in second OT o...        02:31am
# 11  Blog: Kane, Smith-Pelly, Jones, Byfuglien, Gre...        12:02am
# 12  Native of Finland was selected from Wild in ex...        02:58am
# 13  Opening loss has favored Washington feeling pr...        13:23pm
# 14  66-year-old, with third-most NHL wins, 'one of...        20:08pm
# 15  Scored three man-advantage goals in opener vs....        16:02pm
# 16  Watson underrated for Predators; Cirelli, Dona...        16:15pm
# 17  66-year-old will remain with Dallas as consultant        11:11am
# 18  Third-winningest coach in NHL history retired ...        11:32am
# 19  Penalties, special-teams woes sink Toronto in ...        10:46am
# 20  Grubauer starting for Capitals; Henrique, Hert...        10:00am
# 21  NHL.com lists most valuable forwards, defensem...        11:00am
# 22               Penguins, Golden Knights eye history        00:43am
#
#                                                 title
# 0   Kadri suspension has Maple Leafs adjusting for...
# 1   Couturier's transition to scorer for Flyers ev...
# 2   Stanley Cup Playoffs Buzz: Avalanche, Devils t...
# 3   Kings look for Quick to stand tall against Gol...
# 4   Golden Knights make more history with double-o...
# 5   Byfuglien has huge 'impact' for Jets in Game 2...
# 6            Where to watch 2018 Stanley Cup Playoffs
# 7         Fantasy projected lineups, starting goalies
# 8   Kadri suspended three games, out for Maple Lea...
# 9           Flyers stick with plan, respond in Game 2
# 10  Watch every overtime goal in Stanley Cup Playoffs
# 11  Douglas: Players of color have pivotal roles i...
# 12  Get to know Erik Haula, Golden Knights' first ...
# 13  Capitals understand urgency surrounding Game 2...
# 14  Hitchcock praised by Bowman, Babcock upon reti...
# 15     Bruins' power-play surge carries into playoffs
# 16    Fantasy: 10 playoff sleeper candidates for 2018
# 17  Hitchcock retires as Stars coach, third in NHL...
# 18                      Ken Hitchcock career timeline
# 19  Maple Leafs looking for answers after Game 1 l...
# 20    Fantasy: Playoff X-factor for each team in 2018
# 21    Fantasy: Rankings for 2018 Stanley Cup Playoffs
# 22          Stanley Cup Playoffs first-round schedule

# %%
img_re = soup.find_all('img alt',class_ ='mediawall_panel-image swiper-lazy swiper-lazy-loaded').img
img_re
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-a45386467ba4> in <module>()
# ----> 1 img_re = soup.find('img alt',class_ ='mediawall_panel-image swiper-lazy swiper-lazy-loaded').img
#       2 img_re
#
# AttributeError: 'NoneType' object has no attribute 'img'

# %%
img_res = soup.find_all('img',class_='recent-media-navbar-module__image')
img_res[1]
# Out:
# <img class="recent-media-navbar-module__image" data-src="//nhl.bamcontent.com/images/photos/280306162/image/raw.jpg"/>
